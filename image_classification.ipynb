# %%
import tensorflow as tf
from tensorflow.python.keras import layers, models
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# load and prepare the dataset
# Set DATA_DIR to the dataset folder path if needed.
data_dir = os.getenv("DATA_DIR", "/workspaces/image_classification-/data")
if not os.path.isdir(data_dir):
    raise FileNotFoundError(
        f"Dataset directory not found: {data_dir}.\n"
        "Set DATA_DIR to the correct dataset path."
    )

# %%
path = os.path.join(data_dir, "def_front", "cast_def_0_25.jpeg")
if not os.path.isfile(path):
    raise FileNotFoundError(
        f"Image file not found: {path}.\n"
        "Verify the dataset structure and file location."
    )

img = cv2.imdecode(
    np.fromfile(path, dtype=np.uint8),
    cv2.IMREAD_COLOR
)

print(img.shape)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 4
#       1 path = r"C:\Users\verik\Desktop\cnn\casting_512x512\def_front\cast_def_0_25.jpeg"
#       2
#       3 img = cv2.imdecode(
# ----> 4     np.fromfile(path, dtype=np.uint8),
#       5     cv2.IMREAD_COLOR
#       6 )
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\verik\\Desktop\\cnn\\casting_512x512\\def_front\\cast_def_0_25.jpeg'
